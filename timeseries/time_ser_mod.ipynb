# %%
import pandas as pd
import numpy as np

# %%
fin_df = pd.read_csv('../dataset/final_finance_time_series.csv', skiprows = 8)
print(fin_df.columns)
# Out:
# Index(['Reference Code', 'Date Time', 'Description', 'Dr.', 'Cr.', 'Status',
#        'Balance (NPR)', 'Channel', 'Category'],
#       dtype='object')

# %%
print(fin_df['Category'].value_counts())
# Out:
# Category
# Groceries & Shopping    458
# Banking & Finance       427
# Dining & Food           423
# Income                  417
# Subscriptions           410
# Personal Care           402
# Entertainment           400
# Travel                  400
# Education               400
# Housing & Utilities       1
# Name: count, dtype: int64

# %%
def cleaner_function(df):
    df.columns = df.columns.str.strip()
    df = df.dropna(subset = ["Date Time", "Dr.", "Cr.", "Category"])
    df["Date Time"] = pd.to_datetime(df["Date Time"])
    df.set_index("Date Time", inplace = True)
    df.sort_index(inplace = True)
    return df

# %%
fin_df = cleaner_function(fin_df)

# %%
print(fin_df.columns)
# Out:
# Index(['Reference Code', 'Description', 'Dr.', 'Cr.', 'Status',
#        'Balance (NPR)', 'Channel', 'Category'],
#       dtype='object')

# %%
monthly = fin_df.groupby([pd.Grouper(freq = "M"), "Category"])["Dr."].sum().unstack(fill_value=0)

# print(monthly)

print(monthly.index[-1].to_period("M") + 1)

for cat in monthly.columns:
    if sum(monthly[cat]) == 0:
        monthly.drop([cat], axis = 1, inplace=True)

def summation(row):
    total_sum = 0
    for value in row:
        total_sum = total_sum + value
    return total_sum

monthly['Total'] = monthly.apply(lambda x: summation(x), axis = 1)

def percentage(row, col):
    percent = ((row[col] / row["Total"]) * 100)
    return percent

for col in monthly.columns:
    monthly[f"{col} %"] = monthly.apply(lambda x: percentage(x, col), axis = 1)
# Out:
# 2025-07
# C:\Users\swoye\AppData\Local\Temp\ipykernel_21616\3273054278.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly = fin_df.groupby([pd.Grouper(freq = "M"), "Category"])["Dr."].sum().unstack(fill_value=0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
import warnings
warnings.filterwarnings('ignore')

# %%
monthly_income = 500000
target_savings = 90000

# %%
def check_stationary(timeseries, title):
    print(f"Result of Dickey-Fuller Test for {title}: ")
    dftest = adfuller(timeseries, autolag = "AIC")
    dfoutput = pd.Series(dftest[0:4], index = ["Test Statistics", "p-value", "#Lags Used", "Number of Obersvations Used"])
    for key, value in dftest[4].items():
        dfoutput['Critical value (%s)'%key] = value
    print(dfoutput)
    print("Is Stationary:", dftest[1] <= 0.05)
    return dftest[1] <= 0.05

# %%
def find_best_arima_model(data, max_p = 3, max_d = 3, max_q = 3):
    best_aic = np.inf
    best_order = None

    for p in range(max_p + 1):
        for d in range(max_d + 1):
            for q in range(max_q + 1):
                try:
                    arima_model = ARIMA(data, order = (p, d, q))
                    fit_model = arima_model.fit()
                    aic = fit_model.aic
    
                    if aic < best_aic:
                        best_aic = aic
                        best_order = (p, d, q)
                except:
                    continue
    
    return best_order, best_aic

# %%
def forecast_arima(data, order, steps = 1):
    arima_model = ARIMA(data, order=order)
    fitted_model = arima_model.fit()
    forecast = fitted_model.forecast(steps = steps)
    conf_int = fitted_model.get_forecast(steps = steps).conf_int()

    return forecast, conf_int, fitted_model

# %%
def create_budget_forecast(monthly_data, income, target_savings):
    forecasts = {}
    model_summary = {}

    cols = {col for col in monthly_data.columns if not col.endswith(" %") and col != "Total"}

    for col in cols:
        if col in monthly_data.columns:

            data = monthly_data[col].dropna()
            if(len(data) < 3):
                print(f"{col} has insufficient data for ARIMA modelling!!")
                forecasts[col] = data.mean() if len(data) > 0 else 0
                budget = None
                forecast = None
                model_summary = None

                return {}, model_summary, budget

            is_stationary = check_stationary(data, col)
    
            best_order, best_aic = find_best_arima_model(data)
    
            forecast, conf_int, fitted_model = forecast_arima(data, best_order)

            if (forecast.iloc[0] < 0):

                forecast = data.mean()
                forecasts[col] = forecast

                model_summary[col] = {
                'forecast': forecast,
                'aic': 0,
                'order': [0, 0, 0],
                'lower_bound': data.min(),
                'upper_bound': data.max()
                }

                print(f"{col}:")
                print(f"Forecast: {forecast}")
                print(f"Lower Bound: {data.min()}")
                print(f"Upper Bound: {data.max()}")

            else: 
                
                forecasts[col] = forecast.iloc[0]
        
                model_summary[col] = {
                'forecast': forecast.iloc[0],
                'aic': best_aic,
                'order': best_order,
                'lower_bound': conf_int.iloc[0, 0],
                'upper_bound': conf_int.iloc[0, 1]
                }

                print(f"{col}:")
                print(f"Best order: {best_order}")
                print(f"AIC: {best_aic}")
                print(f"Forecast: {forecast.iloc[0]}")
                print(f"Lower Bound: {conf_int.iloc[0, 0]}")
                print(f"Upper Bound: {conf_int.iloc[0, 1]}")

    total_forecast = sum(forecasts.values())
    budget = forecasts.copy()

    available_for_expenses = income - target_savings
    budget_surplus_deficit = available_for_expenses - total_forecast

    print(available_for_expenses)
    print(budget_surplus_deficit)

    if(budget_surplus_deficit > 0):
        print(f"Surplus: {budget_surplus_deficit}")
    elif(budget_surplus_deficit < 0):
        print(f"Deficit: {budget_surplus_deficit}")
    else:
        print("Balanced!!")

    cat_percent = {}

    for category, forecast_value in forecasts.items():
        percentage = (forecast_value / total_forecast) * 100
        cat_percent[category] = percentage
        print(f"{category:<20}: Rs. {forecast_value:>8,.2f} ({percentage:>5.1f}%)")

    if budget_surplus_deficit < 0:
        sorted_categories = sorted(forecasts.items(), key = lambda x:x[1], reverse=True)

        while budget_surplus_deficit < 0:
            made_progress = False  # Track if anything was deducted this round
        
            for i, (category, value) in enumerate(sorted_categories):
                current_value = budget.get(category, 0)
        
                if current_value <= 0:
                    continue  

            # for i, (category, value) in enumerate(sorted_categories):
            #     current_value = budget.get(category, 0)
        
            #     categ_percent = cat_percent[category]

            #     deduction_amount = (categ_percent/100) * value

            #     new_value = current_value - deduction_amount

            #     budget[category] = new_value

            #     budget_surplus_deficit += new_value

            # if budget_surplus_deficit >= -1e-2:
            #     break
        
                p = 50 / (i + 1)
                twt = (20 / 100) * current_value 
        
                if ((p / 100) * abs(budget_surplus_deficit)) < twt:
                    deduction_amount = (p / 100) * abs(budget_surplus_deficit)
                elif (((p / 2) / 100) * abs(budget_surplus_deficit)) < twt:
                    deduction_amount = ((p / 2) / 100) * abs(budget_surplus_deficit)
                elif (((p / 4) / 100) * abs(budget_surplus_deficit)) < twt:
                    deduction_amount = ((p / 4) / 100) * abs(budget_surplus_deficit)
                else:
                    deduction_amount = ((p / 8) / 100) * abs(budget_surplus_deficit)
        
                deduction_amount = min(deduction_amount, current_value)
        
                if deduction_amount <= 0:
                    continue 
        
                new_value = current_value - deduction_amount
                budget[category] = new_value
                budget_surplus_deficit += deduction_amount
                made_progress = True
        
                print(f"\nReducing {category}")
                print(f"Original: {current_value:.2f}")
                print(f"Deduction: {deduction_amount:.2f}")
                print(f"New Value: {new_value:.2f}")
                print(f"Updated Deficit: {budget_surplus_deficit:.2f}")
        
                if budget_surplus_deficit >= 0:
                    break
        
            if not made_progress:
                print("⚠️ No further deductions possible.")
                break
             
    return forecasts, model_summary, budget

# %%
def visualize_forecast(monthly_data, forecasts, model_summary):

    exp_cate = [col for col in monthly_data if not col.endswith(' %') and col != 'Total']

    n_col = 2
    cat_len = len(exp_cate)
    n_row = (cat_len + 1) // n_col + ((cat_len + 1) % n_col > 0)

    fig, axes = plt.subplots(n_row, n_col, figsize = (15, 5*n_row))
    axes = axes.flatten() if n_row > 1 else [axes] if n_col == 1 else axes

    for i, category in enumerate(exp_cate):
        ax = axes[i]

        monthly_data[category].plot(ax = ax, label = "Historical", marker = 'x')

        if category in forecasts:
            forecast_month = monthly_data.index[-1] + pd.DateOffset(month=1)
            ax.scatter(forecast_month, forecasts[category], color = 'red', s = 100, zorder = 5, label = 'Forecast')

            if category in model_summary:
                lower_bound = model_summary[category]['lower_bound']
                upper_bound = model_summary[category]['upper_bound']
                ax.fill_between([forecast_month, forecast_month], [lower_bound, upper_bound], alpha = 0.3, label = 'Confidence Interval')

        ax.set_title(f'{category}: Forecast')
        ax.set_ylabel('Amount')
        ax.legend()
        ax.grid(True, alpha = 0.3)

    plt.tight_layout()
    plt.show()

# %%
def analyze_trends(monthly_data):

    if 'Total' in monthly_data.columns:
        total_expense = monthly_data['Total']

    if len(total_expense) > 4:
        decomposition = seasonal_decompose(total_expense, model = 'additive', period=3)
        
        fig, axes = plt.subplots(4, 1, figsize = (12, 10))
        decomposition.observed.plot(ax = axes[0], title = 'Original')
        decomposition.trend.plot(ax = axes[1], title = 'trend')
        decomposition.seasonal.plot(ax = axes[2], title = 'seasonality')
        decomposition.resid.plot(ax = axes[3], title = 'Residual')
        plt.tight_layout()
        plt.show()

    if len(total_expense) >= 2:
            n_months = len(total_expense)

            growth_rate = ((total_expense.iloc[-1] / total_expense.iloc[0]) ** (1 / (n_months - 1))) - 1
     
            print(f"\nAverage Monthly Growth Rate: {growth_rate * 100:.2f}%")

# %%
forecasts, model_summary, budget = create_budget_forecast(monthly, monthly_income, target_savings)

print(budget)

# visualize_forecast(monthly, forecasts, model_summary)

# analyze_trends(monthly)

# budget_df = pd.DataFrame(budget.items(), columns=['Category', 'Forecast'])
# budget_df.to_csv('budget_forecast.csv', index=False)
# print('Forecast total', sum(forecasts.values()))
# print('Budget total', sum(budget.values()))
# print(f"\nBudget results saved to 'budget_forecast.csv'")
# Out:
# Result of Dickey-Fuller Test for Education:
# Test Statistics               -8.952345e+00
# p-value                        8.655603e-15
# #Lags Used                     0.000000e+00
# Number of Obersvations Used    5.000000e+00
# Critical value (1%)           -6.045114e+00
# Critical value (5%)           -3.929280e+00
# Critical value (10%)          -2.986810e+00
# dtype: float64
# Is Stationary: True
# Education:
# Best order: (1, 3, 1)
# AIC: 65.555879988224
# Forecast: 61042.76132340368
# Lower Bound: 49851.881743122314
# Upper Bound: 72233.64090368505
# Result of Dickey-Fuller Test for Entertainment:
# Test Statistics               -3.936361
# p-value                        0.001783
# #Lags Used                     1.000000
# Number of Obersvations Used    4.000000
# Critical value (1%)           -7.355441
# Critical value (5%)           -4.474365
# Critical value (10%)          -3.126933
# dtype: float64
# Is Stationary: True
# Entertainment:
# Best order: (0, 3, 2)
# AIC: 67.0329031196564
# Forecast: 49149.093816918954
# Lower Bound: 29782.627857512143
# Upper Bound: 68515.55977632577
# Result of Dickey-Fuller Test for Travel:
# Test Statistics               -1.893493
# p-value                        0.335129
# #Lags Used                     0.000000
# Number of Obersvations Used    5.000000
# Critical value (1%)           -6.045114
# Critical value (5%)           -3.929280
# Critical value (10%)          -2.986810
# dtype: float64
# Is Stationary: False
# Travel:
# Best order: (0, 3, 0)
# AIC: 68.4182659979694
# Forecast: 90552.77000000002
# Lower Bound: 62524.76834377124
# Upper Bound: 118580.7716562288
# Result of Dickey-Fuller Test for Subscriptions:
# Test Statistics               -2.217792
# p-value                        0.199852
# #Lags Used                     0.000000
# Number of Obersvations Used    5.000000
# Critical value (1%)           -6.045114
# Critical value (5%)           -3.929280
# Critical value (10%)          -2.986810
# dtype: float64
# Is Stationary: False
# Subscriptions:
# Best order: (1, 3, 0)
# AIC: 66.08175779814498
# Forecast: 35364.799012311196
# Lower Bound: 22446.12297425492
# Upper Bound: 48283.47505036747
# Result of Dickey-Fuller Test for Banking & Finance:
# Test Statistics               -3.350163
# p-value                        0.012780
# #Lags Used                     0.000000
# Number of Obersvations Used    5.000000
# Critical value (1%)           -6.045114
# Critical value (5%)           -3.929280
# Critical value (10%)          -2.986810
# dtype: float64
# Is Stationary: True
# Banking & Finance:
# Best order: (3, 0, 1)
# AIC: 41.20392630739758
# Forecast: 68071.4434175582
# Lower Bound: nan
# Upper Bound: nan
# Result of Dickey-Fuller Test for Groceries & Shopping:
# Test Statistics               -1.916705
# p-value                        0.324244
# #Lags Used                     0.000000
# Number of Obersvations Used    5.000000
# Critical value (1%)           -6.045114
# Critical value (5%)           -3.929280
# Critical value (10%)          -2.986810
# dtype: float64
# Is Stationary: False
# Groceries & Shopping:
# Forecast: 56109.325000000004
# Lower Bound: 49113.95
# Upper Bound: 73625.74
# Result of Dickey-Fuller Test for Dining & Food:
# Test Statistics               -0.212467
# p-value                        0.937019
# #Lags Used                     1.000000
# Number of Obersvations Used    4.000000
# Critical value (1%)           -7.355441
# Critical value (5%)           -4.474365
# Critical value (10%)          -3.126933
# dtype: float64
# Is Stationary: False
# Dining & Food:
# Best order: (1, 3, 1)
# AIC: 63.030525343034626
# Forecast: 62005.19423150902
# Lower Bound: 55126.27284070696
# Upper Bound: 68884.11562231107
# Result of Dickey-Fuller Test for Personal Care:
# Test Statistics               -8.246579e+00
# p-value                        5.533288e-13
# #Lags Used                     1.000000e+00
# Number of Obersvations Used    4.000000e+00
# Critical value (1%)           -7.355441e+00
# Critical value (5%)           -4.474365e+00
# Critical value (10%)          -3.126933e+00
# dtype: float64
# Is Stationary: True
# Personal Care:
# Best order: (1, 3, 0)
# AIC: 65.86554819818068
# Forecast: 59698.68936072266
# Lower Bound: 42869.10201077727
# Upper Bound: 76528.27671066805
# Result of Dickey-Fuller Test for Housing & Utilities:
# Test Statistics               -2.236068
# p-value                        0.193416
# #Lags Used                     0.000000
# Number of Obersvations Used    5.000000
# Critical value (1%)           -6.045114
# Critical value (5%)           -3.929280
# Critical value (10%)          -2.986810
# dtype: float64
# Is Stationary: False
# Housing & Utilities:
# Best order: (3, 3, 1)
# AIC: 28.144112077534217
# Forecast: 0.0006669603370852428
# Lower Bound: -0.021568821454019862
# Upper Bound: 0.022902742128190347
# 410000
# -71994.07682938408
# Deficit: -71994.07682938408
# Education           : Rs. 61,042.76 ( 12.7%)
# Entertainment       : Rs. 49,149.09 ( 10.2%)
# Travel              : Rs. 90,552.77 ( 18.8%)
# Subscriptions       : Rs. 35,364.80 (  7.3%)
# Banking & Finance   : Rs. 68,071.44 ( 14.1%)
# Groceries & Shopping: Rs. 56,109.33 ( 11.6%)
# Dining & Food       : Rs. 62,005.19 ( 12.9%)
# Personal Care       : Rs. 59,698.69 ( 12.4%)
# Housing & Utilities : Rs.     0.00 (  0.0%)
#
# Reducing Travel
# Original: 90552.77
# Deduction: 17998.52
# New Value: 72554.25
# Updated Deficit: -53995.56
#
# Reducing Banking & Finance
# Original: 68071.44
# Deduction: 13498.89
# New Value: 54572.55
# Updated Deficit: -40496.67
#
# Reducing Dining & Food
# Original: 62005.19
# Deduction: 6749.44
# New Value: 55255.75
# Updated Deficit: -33747.22
#
# Reducing Education
# Original: 61042.76
# Deduction: 4218.40
# New Value: 56824.36
# Updated Deficit: -29528.82
#
# Reducing Personal Care
# Original: 59698.69
# Deduction: 2952.88
# New Value: 56745.81
# Updated Deficit: -26575.94
#
# Reducing Groceries & Shopping
# Original: 56109.33
# Deduction: 2214.66
# New Value: 53894.66
# Updated Deficit: -24361.28
#
# Reducing Entertainment
# Original: 49149.09
# Deduction: 1740.09
# New Value: 47409.00
# Updated Deficit: -22621.19
#
# Reducing Subscriptions
# Original: 35364.80
# Deduction: 1413.82
# New Value: 33950.97
# Updated Deficit: -21207.36
#
# Reducing Housing & Utilities
# Original: 0.00
# Deduction: 0.00
# New Value: 0.00
# Updated Deficit: -21207.36
#
# Reducing Travel
# Original: 72554.25
# Deduction: 10603.68
# New Value: 61950.57
# Updated Deficit: -10603.68
#
# Reducing Banking & Finance
# Original: 54572.55
# Deduction: 2650.92
# New Value: 51921.63
# Updated Deficit: -7952.76
#
# Reducing Dining & Food
# Original: 55255.75
# Deduction: 1325.46
# New Value: 53930.29
# Updated Deficit: -6627.30
#
# Reducing Education
# Original: 56824.36
# Deduction: 828.41
# New Value: 55995.95
# Updated Deficit: -5798.89
#
# Reducing Personal Care
# Original: 56745.81
# Deduction: 579.89
# New Value: 56165.92
# Updated Deficit: -5219.00
#
# Reducing Groceries & Shopping
# Original: 53894.66
# Deduction: 434.92
# New Value: 53459.75
# Updated Deficit: -4784.08
#
# Reducing Entertainment
# Original: 47409.00
# Deduction: 341.72
# New Value: 47067.28
# Updated Deficit: -4442.36
#
# Reducing Subscriptions
# Original: 33950.97
# Deduction: 277.65
# New Value: 33673.33
# Updated Deficit: -4164.71
#
# Reducing Travel
# Original: 61950.57
# Deduction: 2082.36
# New Value: 59868.21
# Updated Deficit: -2082.36
#
# Reducing Banking & Finance
# Original: 51921.63
# Deduction: 520.59
# New Value: 51401.04
# Updated Deficit: -1561.77
#
# Reducing Dining & Food
# Original: 53930.29
# Deduction: 260.29
# New Value: 53669.99
# Updated Deficit: -1301.47
#
# Reducing Education
# Original: 55995.95
# Deduction: 162.68
# New Value: 55833.26
# Updated Deficit: -1138.79
#
# Reducing Personal Care
# Original: 56165.92
# Deduction: 113.88
# New Value: 56052.04
# Updated Deficit: -1024.91
#
# Reducing Groceries & Shopping
# Original: 53459.75
# Deduction: 85.41
# New Value: 53374.34
# Updated Deficit: -939.50
#
# Reducing Entertainment
# Original: 47067.28
# Deduction: 67.11
# New Value: 47000.18
# Updated Deficit: -872.39
#
# Reducing Subscriptions
# Original: 33673.33
# Deduction: 54.52
# New Value: 33618.80
# Updated Deficit: -817.87
#
# Reducing Travel
# Original: 59868.21
# Deduction: 408.93
# New Value: 59459.28
# Updated Deficit: -408.93
#
# Reducing Banking & Finance
# Original: 51401.04
# Deduction: 102.23
# New Value: 51298.81
# Updated Deficit: -306.70
#
# Reducing Dining & Food
# Original: 53669.99
# Deduction: 51.12
# New Value: 53618.88
# Updated Deficit: -255.58
#
# Reducing Education
# Original: 55833.26
# Deduction: 31.95
# New Value: 55801.31
# Updated Deficit: -223.64
#
# Reducing Personal Care
# Original: 56052.04
# Deduction: 22.36
# New Value: 56029.68
# Updated Deficit: -201.27
#
# Reducing Groceries & Shopping
# Original: 53374.34
# Deduction: 16.77
# New Value: 53357.56
# Updated Deficit: -184.50
#
# Reducing Entertainment
# Original: 47000.18
# Deduction: 13.18
# New Value: 46987.00
# Updated Deficit: -171.32
#
# Reducing Subscriptions
# Original: 33618.80
# Deduction: 10.71
# New Value: 33608.10
# Updated Deficit: -160.61
#
# Reducing Travel
# Original: 59459.28
# Deduction: 80.31
# New Value: 59378.97
# Updated Deficit: -80.31
#
# Reducing Banking & Finance
# Original: 51298.81
# Deduction: 20.08
# New Value: 51278.73
# Updated Deficit: -60.23
#
# Reducing Dining & Food
# Original: 53618.88
# Deduction: 10.04
# New Value: 53608.84
# Updated Deficit: -50.19
#
# Reducing Education
# Original: 55801.31
# Deduction: 6.27
# New Value: 55795.04
# Updated Deficit: -43.92
#
# Reducing Personal Care
# Original: 56029.68
# Deduction: 4.39
# New Value: 56025.28
# Updated Deficit: -39.53
#
# Reducing Groceries & Shopping
# Original: 53357.56
# Deduction: 3.29
# New Value: 53354.27
# Updated Deficit: -36.23
#
# Reducing Entertainment
# Original: 46987.00
# Deduction: 2.59
# New Value: 46984.41
# Updated Deficit: -33.64
#
# Reducing Subscriptions
# Original: 33608.10
# Deduction: 2.10
# New Value: 33605.99
# Updated Deficit: -31.54
#
# Reducing Travel
# Original: 59378.97
# Deduction: 15.77
# New Value: 59363.20
# Updated Deficit: -15.77
#
# Reducing Banking & Finance
# Original: 51278.73
# Deduction: 3.94
# New Value: 51274.79
# Updated Deficit: -11.83
#
# Reducing Dining & Food
# Original: 53608.84
# Deduction: 1.97
# New Value: 53606.87
# Updated Deficit: -9.86
#
# Reducing Education
# Original: 55795.04
# Deduction: 1.23
# New Value: 55793.81
# Updated Deficit: -8.62
#
# Reducing Personal Care
# Original: 56025.28
# Deduction: 0.86
# New Value: 56024.42
# Updated Deficit: -7.76
#
# Reducing Groceries & Shopping
# Original: 53354.27
# Deduction: 0.65
# New Value: 53353.62
# Updated Deficit: -7.12
#
# Reducing Entertainment
# Original: 46984.41
# Deduction: 0.51
# New Value: 46983.90
# Updated Deficit: -6.61
#
# Reducing Subscriptions
# Original: 33605.99
# Deduction: 0.41
# New Value: 33605.58
# Updated Deficit: -6.19
#
# Reducing Travel
# Original: 59363.20
# Deduction: 3.10
# New Value: 59360.10
# Updated Deficit: -3.10
#
# Reducing Banking & Finance
# Original: 51274.79
# Deduction: 0.77
# New Value: 51274.02
# Updated Deficit: -2.32
#
# Reducing Dining & Food
# Original: 53606.87
# Deduction: 0.39
# New Value: 53606.48
# Updated Deficit: -1.94
#
# Reducing Education
# Original: 55793.81
# Deduction: 0.24
# New Value: 55793.57
# Updated Deficit: -1.69
#
# Reducing Personal Care
# Original: 56024.42
# Deduction: 0.17
# New Value: 56024.25
# Updated Deficit: -1.52
#
# Reducing Groceries & Shopping
# Original: 53353.62
# Deduction: 0.13
# New Value: 53353.50
# Updated Deficit: -1.40
#
# Reducing Entertainment
# Original: 46983.90
# Deduction: 0.10
# New Value: 46983.80
# Updated Deficit: -1.30
#
# Reducing Subscriptions
# Original: 33605.58
# Deduction: 0.08
# New Value: 33605.50
# Updated Deficit: -1.22
#
# Reducing Travel
# Original: 59360.10
# Deduction: 0.61
# New Value: 59359.50
# Updated Deficit: -0.61
#
# Reducing Banking & Finance
# Original: 51274.02
# Deduction: 0.15
# New Value: 51273.87
# Updated Deficit: -0.46
#
# Reducing Dining & Food
# Original: 53606.48
# Deduction: 0.08
# New Value: 53606.41
# Updated Deficit: -0.38
#
# Reducing Education
# Original: 55793.57
# Deduction: 0.05
# New Value: 55793.52
# Updated Deficit: -0.33
#
# Reducing Personal Care
# Original: 56024.25
# Deduction: 0.03
# New Value: 56024.22
# Updated Deficit: -0.30
#
# Reducing Groceries & Shopping
# Original: 53353.50
# Deduction: 0.02
# New Value: 53353.47
# Updated Deficit: -0.27
#
# Reducing Entertainment
# Original: 46983.80
# Deduction: 0.02
# New Value: 46983.78
# Updated Deficit: -0.25
#
# Reducing Subscriptions
# Original: 33605.50
# Deduction: 0.02
# New Value: 33605.48
# Updated Deficit: -0.24
#
# Reducing Travel
# Original: 59359.50
# Deduction: 0.12
# New Value: 59359.38
# Updated Deficit: -0.12
#
# Reducing Banking & Finance
# Original: 51273.87
# Deduction: 0.03
# New Value: 51273.84
# Updated Deficit: -0.09
#
# Reducing Dining & Food
# Original: 53606.41
# Deduction: 0.01
# New Value: 53606.39
# Updated Deficit: -0.07
#
# Reducing Education
# Original: 55793.52
# Deduction: 0.01
# New Value: 55793.51
# Updated Deficit: -0.07
#
# Reducing Personal Care
# Original: 56024.22
# Deduction: 0.01
# New Value: 56024.21
# Updated Deficit: -0.06
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.05
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.05
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.05
#
# Reducing Travel
# Original: 59359.38
# Deduction: 0.02
# New Value: 59359.35
# Updated Deficit: -0.02
#
# Reducing Banking & Finance
# Original: 51273.84
# Deduction: 0.01
# New Value: 51273.83
# Updated Deficit: -0.02
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.01
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.01
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.01
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.01
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.01
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.01
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# ...
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Education
# Original: 55793.51
# Deduction: 0.00
# New Value: 55793.51
# Updated Deficit: -0.00
#
# Reducing Personal Care
# Original: 56024.21
# Deduction: 0.00
# New Value: 56024.21
# Updated Deficit: -0.00
#
# Reducing Groceries & Shopping
# Original: 53353.47
# Deduction: 0.00
# New Value: 53353.47
# Updated Deficit: -0.00
#
# Reducing Entertainment
# Original: 46983.78
# Deduction: 0.00
# New Value: 46983.78
# Updated Deficit: -0.00
#
# Reducing Subscriptions
# Original: 33605.48
# Deduction: 0.00
# New Value: 33605.48
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
#
# Reducing Banking & Finance
# Original: 51273.83
# Deduction: 0.00
# New Value: 51273.83
# Updated Deficit: -0.00
#
# Reducing Dining & Food
# Original: 53606.39
# Deduction: 0.00
# New Value: 53606.39
# Updated Deficit: -0.00
#
# Reducing Travel
# Original: 59359.35
# Deduction: 0.00
# New Value: 59359.35
# Updated Deficit: -0.00
# ⚠️ No further deductions possible.
# {'Education': 55793.506523012235, 'Entertainment': 46983.776211757475, 'Travel': 59359.346969681435, 'Subscriptions': 33605.4784581175, 'Banking & Finance': 51273.82805630554, 'Groceries & Shopping': 53353.4662297945, 'Dining & Food': 53606.38655088269, 'Personal Care': 56024.21100044864, 'Housing & Utilities': 0.0}

# %%
dict1 = {'Education': 55793.506523012235, 'Entertainment': 46983.776211757475, 'Travel': 59359.346969681435, 'Subscriptions': 33605.4784581175, 'Banking & Finance': 51273.82805630554, 'Groceries & Shopping': 53353.4662297945, 'Dining & Food': 53606.38655088269, 'Personal Care': 56024.21100044864, 'Housing & Utilities': 0.0}
dict2 = {'Education': 55793.506523012235, 'Entertainment': 46983.776211757475, 'Travel': 59359.346969681435, 'Subscriptions': 33605.4784581175, 'Banking & Finance': 51273.82805630554, 'Groceries & Shopping': 53353.4662297945, 'Dining & Food': 53606.38655088269, 'Personal Care': 56024.21100044864, 'Housing & Utilities': 0.0}
new_dict = {'Category': [], 'B_Amount': [], 'F_Amount': []}

for key, value in dict1.items():
    new_dict['Category'].append(key)
    new_dict['B_Amount'].append(value)

for values in dict2.values():
    new_dict['F_Amount'].append(values)

print(new_dict)

df = pd.DataFrame(new_dict)
print(df)
# Out:
# {'Category': ['Education', 'Entertainment', 'Travel', 'Subscriptions', 'Banking & Finance', 'Groceries & Shopping', 'Dining & Food', 'Personal Care', 'Housing & Utilities'], 'B_Amount': [55793.506523012235, 46983.776211757475, 59359.346969681435, 33605.4784581175, 51273.82805630554, 53353.4662297945, 53606.38655088269, 56024.21100044864, 0.0], 'F_Amount': [55793.506523012235, 46983.776211757475, 59359.346969681435, 33605.4784581175, 51273.82805630554, 53353.4662297945, 53606.38655088269, 56024.21100044864, 0.0]}
#                Category      B_Amount      F_Amount
# 0             Education  55793.506523  55793.506523
# 1         Entertainment  46983.776212  46983.776212
# 2                Travel  59359.346970  59359.346970
# 3         Subscriptions  33605.478458  33605.478458
# 4     Banking & Finance  51273.828056  51273.828056
# 5  Groceries & Shopping  53353.466230  53353.466230
# 6         Dining & Food  53606.386551  53606.386551
# 7         Personal Care  56024.211000  56024.211000
# 8   Housing & Utilities      0.000000      0.000000
